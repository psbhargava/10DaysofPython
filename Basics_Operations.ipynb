# %% [markdown]
# ## Jupyter Notebook

# %%
print ("welcome to the course!")
# Out:
# welcome to the course!

# %%
print ("welcome to the course") # shift + enter
# Out:
# welcome to the course

# %%
print ("welcome to the course...")
# Out:
# welcome to the course...

# %% [markdown]
# # Adding Comments

# %%
# this is one way of adding a comment
print ("it's so cold today...")
# Out:
# it's so cold today...

# %% [markdown]
# This is a markdown cell

# %%
 num = 9 # shift + enter

# %%
num
# Out:
# 9

# %% [markdown]
# ### Introduction to Python
# #### Scalar Data Types and Operations
# Python has four scalar data types:
#   * Integer
#   * Float
#   * Boolean
#   * Complex
#
# We will review these in this notebook

# %% [markdown]
# #### Integers
# The usual arithmetic operators are available: + for addition, - for subtraction and * for multiplication.

# %%
print(2 + 4)
print(12878 + 1)
print(7 - 3)
print(127 - 128)
print(8 * 6)
print(17 * 12)
# Out:
# 6
# 12879
# 4
# -1
# 48
# 204

# %% [markdown]
# There are *two* division operators: / for everyday (float) division and // for truncating (integer) division

# %%
print(17 / 4)
print(17 // 4)
# Out:
# 4.25
# 4

# %% [markdown]
# The modulo operator % and the exponentiation operator ** are also available.

# %%
print(18 % 3)
print(72 % 5)
# Out:
# 0
# 2

# %% [markdown]
# The usual operator precedence rules and use of parentheses to override that are available

# %%
print(10 ** 2 * 7 - 3)
print(10 ** (2 * 7) - 3)
print(10 ** (2 * 7 - 3))
# Out:
# 697
# 99999999999997
# 100000000000

# %%
a = 123456789 
b = a ** 2
c = b ** 3
d = c ** 4
e = d ** 5
print(e)
print(len(str(e)))
# Out:
# ...
# 971

# %% [markdown]
# #### Assignment operators
# The standard assignment operators are available. That is,  $\alpha$  $\odot=\beta$ is a shorthand for $\alpha = \alpha \odot \beta$
# where $\odot$ is any binary arithmetic operator we saw above

# %%
a = 12
b = 5
a += b
print(a, b)
a -= b
print(a, b)
a *= b
print(a, b)
# Out:
# 17 5
# 12 5
# 60 5

# %% [markdown]
# #### Boolean
# The two constants True and False are defined.
#
# The usual boolean operators are also available: ==, !=, >, >=, <, <=

# %%
a = 12
b = 13
print(a == b - 1,a == b, a != b, a < b, a >= b)
# Out:
# True False True True False

# %% [markdown]
# #### Float
# Python has a float datatype (and it is the same as C's double!) and the above operations are available

# %%
a = 12.9
b = 3.6
c = a + b
d = a - b
e = a * b #Watch out for the round off error!
f = a / b
print(a, b, c, d, e, f, sep="\n")
# Out:
# 12.9
# 3.6
# 16.5
# 9.3
# 46.440000000000005
# 3.5833333333333335

# %%
##### UNDERSTAND FLOATING POINT IS ALWAYS APPROXIMATE!
print(2/3)
##### NEVER COMPARE floats FOR EQUALITY
print(12.9 * 3.6 == 46.44)
print(12.9 * 3.6 - 46.44)
EPSILON = 0.0000001
print(abs(12.9 * 3.6 - 46.44) <= EPSILON)
# Out:
# 0.6666666666666666
# False
# 7.105427357601002e-15
# True

# %% [markdown]
# #### Complex
# Complex numbers are built-in

# %%
z = 3 - 4j
print(z, z.real, z.imag, abs(z), sep="\n")
# Out:
# (3-4j)
# 3.0
# -4.0
# 5.0

# %%
x = 5 + 12j

# %%
print(z + x, z - x, z * x, x / z, sep="\n")
# Out:
# (8+8j)
# (-2-16j)
# (63+16j)
# (-1.32+2.24j)

# %% [markdown]
# #### Variables
# We have been using variables already. Python variable naming rules are simple and similar to all major programming languages
#  * must start with a letter
#  * can have letters, numbers and underscore
#  * case sensitive
#
# ### **Note that we need not declare variables but using an undefined variable is an error**

# %%
z = 3 - 4*j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e899f1a1703e> in <module>()
# ----> 1 z = 3 - 4*j
#
# NameError: name 'j' is not defined

# %%
z = 3 - 4j
z
# Out:
# (3-4j)

# %%
a = 12.9
b = 3.6
a * b
# Out:
# 46.440000000000005

# %%
print(2/3)
# Out:
# 0.6666666666666666

# %%
z1 = 5 + 7j
type(z1)
# Out:
# complex

# %%
x = 5 # shift + enter

# %%
X = 7

# %%
_x = 8

# %%
x
# Out:
# 5

# %%
X
# Out:
# 7

# %%
_x
# Out:
# 8

# %%
My_number = 45

# %%
My_number
# Out:
# 45

# %%
%, $
# Out:
# UsageError: Line magic function `%,` not found.

# %%
# %x = 22
# Out:
# UsageError: Line magic function `%x` not found.

# %%
$x = 4
# Out:
#   File "<ipython-input-41-9b9b6047123e>", line 1
#     $x = 4
#     ^
# SyntaxError: invalid syntax

# %%
my_num = 7

# %%
MY_NUM = 9

# %%
my_num
# Out:
# 7

# %%
MY_NUM
# Out:
# 9

# %%
keywords = reserved words
# Out:
#   File "<ipython-input-46-a7e4410d6b4a>", line 1
#     keywords = reserved words
#                             ^
# SyntaxError: invalid syntax

# %%
if = 5
# Out:
#   File "<ipython-input-47-1a9bb92cc795>", line 1
#     if = 5
#        ^
# SyntaxError: invalid syntax

# %%
except = 8
# Out:
#   File "<ipython-input-48-1d5212a589aa>", line 1
#     except = 8
#          ^
# SyntaxError: invalid syntax

# %%
# LINES and INDENTATION

# %%
print "x is 5"
# Out:
#   File "<ipython-input-50-9d30dc59ad17>", line 1
#     print "x is 5"
#                  ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("x is 5")?

# %%
i = 8

# %%
i
# Out:
# 8

# %%
if i == 9:
    print "the value of i is 9"
else:
    print "the value of i is not 9"
# Out:
#   File "<ipython-input-53-8a7e75a0f5f9>", line 2
#     print "the value of i is 9"
#                               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("the value of i is 9")?

# %%
print("this statement will be printed")
# Out:
# this statement will be printed

# %%
print('this statement will be printed')
# Out:
# this statement will be printed

# %%
print('I'm cold')
# Out:
#   File "<ipython-input-56-7222cea86731>", line 1
#     print('I'm cold')
#              ^
# SyntaxError: invalid syntax

# %%
print("I'm cold")
# Out:
# I'm cold

# %%
print('He said, "he would be there in a few hours".')
# Out:
# He said, "he would be there in a few hours".

# %%
# this is a comment

# %%
# a function to add two numbers
def add_num(x,y):
    return x + y

# %%
# comment goes here
print "the value of x and y is: " # comment can go here too
# Out:
#   File "<ipython-input-66-5aedd1d3f263>", line 1
#     print "the value of x and y is: " # comment can go here too
#                                     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("the value of x and y is: " # comment can go here too)?

# %%
input("please choose a number: ") # this will prompt a user to enter a number
# Out:
# please choose a number: 4
# '4'

# %%
print("this is going to be a long comment and it needs to continue on a new line, \
don't you agree? You see how long the statement is?this is going to be a long comment\
and it needs to continue on a new line, don't you agree? You see how long the statement is?\
this is going to be a long comment and it needs to continue on a new line, don't you agree?\
You see how long the statement is?this is going to be a long comment and it needs to continue\
on a new line,don't you agree? You see how long the statement is?")
# Out:
# this is going to be a long comment and it needs to continue on a new line, don't you agree? You see how long the statement is?this is going to be a long commentand it needs to continue on a new line, don't you agree? You see how long the statement is?this is going to be a long comment and it needs to continue on a new line, don't you agree?You see how long the statement is?this is going to be a long comment and it needs to continueon a new line,don't you agree? You see how long the statement is?

# %%
"""
this is going to be a long comment and it needs to continue on a new line, 
don't you agree? You see how long the statement is?this is going to be a long comment
and it needs to continue on a new line, don't you agree?

"""
print("the value of 3 + 6 is: "), 3+6
# Out:
# the value of 3 + 6 is:
# (None, 9)

# %%
print("hi there \n how are you? \t I am good.)"
# Out:
#   File "<ipython-input-71-ed3b072ca5b3>", line 1
#     print("hi there \n how are you? \t I am good.)"
#                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
'''
this is going to be a long comment and it needs to continue on a new line, 
don't you agree? You see how long the statement is?this is going to be a long comment
and it needs to continue on a new line, don't you agree? doc string

'''

print("the value of x is 5")
# Out:
# the value of x is 5
